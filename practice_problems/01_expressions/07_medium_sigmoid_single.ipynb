# %% [markdown]
# # Apply the Sigmoid Activation Function
#
# **Chapter:** Expressions &nbsp;·&nbsp; **Difficulty:** Medium &nbsp;·&nbsp; **ML/Stats concept:** Neural Networks
#
# ### Problem
# The **sigmoid** function squashes any real number into the range `(0, 1)`, producing a
# probability-like output. It's used by logistic regression and every neuron in a basic
# neural network:
#
# ```
# sigmoid(x) = 1 / (1 + e^(-x))
# ```
#
# ```
# x = 2.5
# ```
#
# Use `math.exp` to write a single expression for `sigmoid(x)`, storing it in `activation`.

# %%
import math

x = 2.5

# TODO: compute sigmoid(x) as a single expression, using math.exp
activation = None

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
import math

expected = 1 / (1 + math.exp(-x))
assert activation is not None, "activation is still None -- fill in the expression above."
assert math.isclose(activation, expected), f"Expected {expected}, got {activation}"
print("All tests passed! activation =", activation)

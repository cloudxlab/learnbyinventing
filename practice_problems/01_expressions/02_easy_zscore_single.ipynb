# %% [markdown]
# # Compute a Single Z-Score
#
# **Chapter:** Expressions &nbsp;·&nbsp; **Difficulty:** Easy &nbsp;·&nbsp; **ML/Stats concept:** Descriptive Statistics
#
# ### Problem
# A **z-score** tells you how many standard deviations a value `x` is away from the mean `mu`,
# given the standard deviation `sigma`:
#
# ```
# z = (x - mu) / sigma
# ```
#
# Z-scores are the foundation of outlier detection — values with a large `|z|` are unusual.
#
# ```
# x = 82
# mu = 70
# sigma = 8
# ```
#
# Write a single expression that computes the z-score and stores it in `z_score`.

# %%
x = 82
mu = 70
sigma = 8

# TODO: compute the z-score of x as a single expression
z_score = None

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
import math

expected = (x - mu) / sigma
assert z_score is not None, "z_score is still None -- fill in the expression above."
assert math.isclose(z_score, expected), f"Expected {expected}, got {z_score}"
print("All tests passed! z_score =", z_score)

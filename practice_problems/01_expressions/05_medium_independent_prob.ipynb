# %% [markdown]
# # Probability of Two Independent Events
#
# **Chapter:** Expressions &nbsp;·&nbsp; **Difficulty:** Medium &nbsp;·&nbsp; **ML/Stats concept:** Probability
#
# ### Problem
# For two **independent** events A and B, the probability that both happen is:
#
# ```
# P(A and B) = P(A) * P(B)
# ```
#
# This is also the assumption behind Naive Bayes, which multiplies feature probabilities together.
#
# ```
# p_rain = 0.3      # probability it rains today
# p_traffic = 0.6   # probability of heavy traffic today
# ```
#
# Write a single expression for the probability that it rains **and** there's heavy traffic,
# storing it in `p_both`.

# %%
p_rain = 0.3
p_traffic = 0.6

# TODO: probability that BOTH independent events happen
p_both = None

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
import math

expected = p_rain * p_traffic
assert p_both is not None, "p_both is still None -- fill in the expression above."
assert math.isclose(p_both, expected), f"Expected {expected}, got {p_both}"
print("All tests passed! p_both =", p_both)

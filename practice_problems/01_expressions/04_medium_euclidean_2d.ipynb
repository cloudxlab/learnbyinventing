# %% [markdown]
# # Euclidean Distance Between Two Points
#
# **Chapter:** Expressions &nbsp;·&nbsp; **Difficulty:** Medium &nbsp;·&nbsp; **ML/Stats concept:** Distance Metrics
#
# ### Problem
# **Euclidean distance** measures how far apart two points are — it's the core idea behind
# k-Nearest Neighbors ("how similar are two data points?"):
#
# ```
# distance = sqrt((x1 - x2)**2 + (y1 - y2)**2)
# ```
#
# ```
# x1, y1 = 2, 3
# x2, y2 = 7, 11
# ```
#
# Write a single expression that computes the distance and stores it in `distance`.
# (You can use `** 0.5` for the square root, no need to import `math`.)
#
#
# **Write your solution in `exercises/04_medium_euclidean_2d.py`**

# %%
x1, y1 = 2, 3
x2, y2 = 7, 11

# TODO: compute the Euclidean distance between (x1, y1) and (x2, y2)
distance = None

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
import math

expected = ((x1 - x2) ** 2 + (y1 - y2) ** 2) ** 0.5
assert distance is not None, "distance is still None -- fill in the expression above."
assert math.isclose(distance, expected), f"Expected {expected}, got {distance}"
print("All tests passed! distance =", distance)

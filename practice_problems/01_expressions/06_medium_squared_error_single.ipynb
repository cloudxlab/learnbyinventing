# %% [markdown]
# # Squared Error for One Prediction
#
# **Chapter:** Expressions &nbsp;·&nbsp; **Difficulty:** Medium &nbsp;·&nbsp; **ML/Stats concept:** Regression
#
# ### Problem
# The squared error for a single prediction is:
#
# ```
# squared_error = (y_true - y_pred) ** 2
# ```
#
# Averaging this over many samples gives **Mean Squared Error (MSE)** — the most common loss
# function for regression models. Here you'll compute it for just one sample.
#
# ```
# y_true = 50
# y_pred = 42
# ```
#
# Write a single expression for the squared error, storing it in `squared_error`.
#
#
# **Write your solution in `exercises/06_medium_squared_error_single.py`**

# %%
y_true = 50
y_pred = 42

# TODO: compute the squared error of this one prediction
squared_error = None

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
import math

expected = (y_true - y_pred) ** 2
assert squared_error is not None, "squared_error is still None -- fill in the expression above."
assert math.isclose(squared_error, expected), f"Expected {expected}, got {squared_error}"
print("All tests passed! squared_error =", squared_error)

# %% [markdown]
# # One Term of a Covariance Sum
#
# **Chapter:** Expressions &nbsp;·&nbsp; **Difficulty:** Hard &nbsp;·&nbsp; **ML/Stats concept:** Correlation
#
# ### Problem
# **Covariance** measures whether two variables tend to move together. It's computed by
# averaging terms of the form:
#
# ```
# (x_i - x_mean) * (y_i - y_mean)
# ```
#
# over every data point. Before looping over a whole dataset (a later chapter), compute just
# **one** such term for a single point:
#
# ```
# x, x_mean = 5, 4
# y, y_mean = 12, 9
# ```
#
# Write a single expression for this term, storing it in `term`.

# %%
x, x_mean = 5, 4
y, y_mean = 12, 9

# TODO: compute (x - x_mean) * (y - y_mean)
term = None

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
import math

expected = (x - x_mean) * (y - y_mean)
assert term is not None, "term is still None -- fill in the expression above."
assert math.isclose(term, expected), f"Expected {expected}, got {term}"
print("All tests passed! term =", term)

# %% [markdown]
# # One Gradient Descent Update Step
#
# **Chapter:** Expressions &nbsp;·&nbsp; **Difficulty:** Hard &nbsp;·&nbsp; **ML/Stats concept:** Gradient Descent
#
# ### Problem
# Every neural network learns through repeated applications of this single update rule:
#
# ```
# new_w = w - learning_rate * gradient
# ```
#
# ```
# w = 4.0
# learning_rate = 0.1
# gradient = 2.5
# ```
#
# Write a single expression for the updated weight, storing it in `new_w`.
#
#
# **Write your solution in `exercises/09_hard_gradient_step_single.py`**

# %%
w = 4.0
learning_rate = 0.1
gradient = 2.5

# TODO: apply one gradient descent update step
new_w = None

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
import math

expected = w - learning_rate * gradient
assert new_w is not None, "new_w is still None -- fill in the expression above."
assert math.isclose(new_w, expected), f"Expected {expected}, got {new_w}"
print("All tests passed! new_w =", new_w)

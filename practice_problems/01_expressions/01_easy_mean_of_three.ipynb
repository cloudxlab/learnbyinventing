# %% [markdown]
# # Find the Mean of Three Numbers
#
# **Chapter:** Expressions &nbsp;·&nbsp; **Difficulty:** Easy &nbsp;·&nbsp; **ML/Stats concept:** Descriptive Statistics
#
# ### Problem
# You're given three numbers — temperatures recorded on three different days:
#
# ```
# a = 21
# b = 19
# c = 26
# ```
#
# Write a single expression that computes their **mean** (average) and store it in a variable
# called `mean_value`.
#
# Formula: `mean = (a + b + c) / 3`
#
# This is the building block behind almost every statistic you'll compute later — variance,
# standard deviation, normalization, and more all start from the mean.
#
#
# **Write your solution in `exercises/01_easy_mean_of_three.py`**

# %%
a = 21
b = 19
c = 26

# TODO: compute the mean of a, b, c as a single expression
mean_value = None

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
import math

expected = (a + b + c) / 3
assert mean_value is not None, "mean_value is still None -- fill in the expression above."
assert math.isclose(mean_value, expected), f"Expected {expected}, got {mean_value}"
print("All tests passed! mean_value =", mean_value)

# %% [markdown]
# # Min-Max Scale a Single Value
#
# **Chapter:** Expressions &nbsp;·&nbsp; **Difficulty:** Easy &nbsp;·&nbsp; **ML/Stats concept:** Normalization
#
# ### Problem
# Before feeding numeric features into most ML models, it's common to rescale them into the
# `[0, 1]` range using **min-max scaling**:
#
# ```
# scaled = (x - min_val) / (max_val - min_val)
# ```
#
# ```
# x = 150
# min_val = 100
# max_val = 200
# ```
#
# Write a single expression that computes the scaled value and stores it in `scaled`.

# %%
x = 150
min_val = 100
max_val = 200

# TODO: min-max scale x into the [0, 1] range as a single expression
scaled = None

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
import math

expected = (x - min_val) / (max_val - min_val)
assert scaled is not None, "scaled is still None -- fill in the expression above."
assert math.isclose(scaled, expected), f"Expected {expected}, got {scaled}"
print("All tests passed! scaled =", scaled)

# %% [markdown]
# # Write a std_dev() Function (Using variance())
#
# **Chapter:** Functions &nbsp;·&nbsp; **Difficulty:** Easy &nbsp;·&nbsp; **ML/Stats concept:** Descriptive Statistics
#
# ### Problem
# `mean()` and `variance()` are provided below, already working. Write `std_dev(data)` that
# returns the population standard deviation by calling `variance(data)` internally.
#
# ```python
# def std_dev(data):
#     ...
# ```
#
#
# **Write your solution in `exercises/03_easy_std_dev_function.py`**

# %%
def mean(data):
    """Provided utility -- already implemented, no need to change."""
    return sum(data) / len(data)


def variance(data):
    """Provided utility -- already implemented, no need to change."""
    avg = mean(data)
    return sum((x - avg) ** 2 for x in data) / len(data)


def std_dev(data):
    """Return the population standard deviation of a list of numbers.

    TODO: implement using variance(data) internally.
    """
    pass

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
import math
import random
import statistics

random.seed(2)
for _ in range(5):
    sample = [random.uniform(-50, 50) for _ in range(random.randint(2, 20))]
    assert math.isclose(std_dev(sample), statistics.pstdev(sample)), f"std_dev({sample}) is wrong"
print("All tests passed!")

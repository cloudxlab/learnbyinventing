# %% [markdown]
# # Build a Linear Regression Pipeline From Smaller Functions
#
# **Chapter:** Functions &nbsp;·&nbsp; **Difficulty:** Hard &nbsp;·&nbsp; **ML/Stats concept:** Linear Regression
#
# ### Problem
# Implement three functions that work together as a tiny linear regression pipeline:
#
# ```python
# def predict(x, slope, intercept):
#     # slope * x + intercept
#     ...
#
# def mse(y_true_list, y_pred_list):
#     # mean of (y_true - y_pred) ** 2 over all samples
#     ...
#
# def gradient_descent_fit(x_list, y_list, learning_rate, epochs):
#     # start slope = 0, intercept = 0
#     # repeat `epochs` times:
#     #   preds = [predict(x, slope, intercept) for x in x_list]   <-- use predict()!
#     #   errors = [y - p for y, p in zip(y_list, preds)]
#     #   n = len(x_list)
#     #   d_slope = -2 / n * sum(x * e for x, e in zip(x_list, errors))
#     #   d_intercept = -2 / n * sum(errors)
#     #   slope -= learning_rate * d_slope
#     #   intercept -= learning_rate * d_intercept
#     # return slope, intercept
#     ...
# ```
#
# `gradient_descent_fit` should call `predict()` inside its loop rather than recomputing
# `slope * x + intercept` directly.
#
#
# **Write your solution in `exercises/08_hard_regression_pipeline_functions.py`**

# %%
def predict(x, slope, intercept):
    """Return the predicted y for a given x, slope, and intercept."""
    # TODO: implement
    pass


def mse(y_true_list, y_pred_list):
    """Return the mean squared error between two equal-length lists."""
    # TODO: implement
    pass


def gradient_descent_fit(x_list, y_list, learning_rate, epochs):
    """Fit y = slope * x + intercept to the data using gradient descent.

    Start slope = intercept = 0.0, run `epochs` update steps (see the
    formulas in the markdown cell above), and return (slope, intercept).
    Call predict() inside your loop.
    """
    slope, intercept = 0.0, 0.0
    # TODO: implement the training loop
    return slope, intercept

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
import math

assert math.isclose(predict(2, 3, 1), 7)

y_pred_sample = [predict(xi, 3, 1) for xi in [0, 1, 2, 3, 4, 5]]
assert math.isclose(mse([1, 4, 7, 10, 13, 16], y_pred_sample), 0.0, abs_tol=1e-9)

x_list = [0, 1, 2, 3, 4, 5]
y_list = [1, 4, 7, 10, 13, 16]  # y = 3x + 1
slope, intercept = gradient_descent_fit(x_list, y_list, learning_rate=0.01, epochs=2000)
assert abs(slope - 3) < 0.3, f"slope {slope} did not converge close to 3"
assert abs(intercept - 1) < 0.3, f"intercept {intercept} did not converge close to 1"
print("All tests passed! slope =", slope, "intercept =", intercept)

# %% [markdown]
# # Write a variance() Function (Using mean())
#
# **Chapter:** Functions &nbsp;·&nbsp; **Difficulty:** Easy &nbsp;·&nbsp; **ML/Stats concept:** Descriptive Statistics
#
# ### Problem
# `mean()` is provided below, already working. Write `variance(data)` that computes the
# **population** variance — and have it call `mean(data)` internally instead of recomputing the
# mean by hand. This is your first taste of function composition.
#
# ```python
# def variance(data):
#     ...
# ```

# %%
def mean(data):
    """Provided utility -- already implemented, no need to change."""
    return sum(data) / len(data)


def variance(data):
    """Return the population variance of a list of numbers.

    TODO: implement using mean(data) internally (call your mean()
    function -- don't recompute the mean with raw sum()/len() again).
    """
    pass

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
import math
import random
import statistics

random.seed(1)
for _ in range(5):
    sample = [random.uniform(-50, 50) for _ in range(random.randint(2, 20))]
    assert math.isclose(variance(sample), statistics.pvariance(sample)), f"variance({sample}) is wrong"
print("All tests passed!")

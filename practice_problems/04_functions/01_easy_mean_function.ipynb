# %% [markdown]
# # Write a mean() Function
#
# **Chapter:** Functions &nbsp;·&nbsp; **Difficulty:** Easy &nbsp;·&nbsp; **ML/Stats concept:** Descriptive Statistics
#
# ### Problem
# Wrap the mean computation into a reusable function that works on **any** list:
#
# ```python
# def mean(data):
#     ...
# ```
#
#
# **Write your solution in `exercises/01_easy_mean_function.py`**

# %%
def mean(data):
    """Return the arithmetic mean of a list of numbers."""
    # TODO: implement
    pass


# quick manual check while developing -- feel free to change this
sample = [4, 8, 6, 5, 3]
print(mean(sample))

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
import math
import random
import statistics

random.seed(0)
for _ in range(5):
    sample = [random.uniform(-100, 100) for _ in range(random.randint(1, 20))]
    assert math.isclose(mean(sample), statistics.mean(sample)), f"mean({sample}) is wrong"
print("All tests passed!")

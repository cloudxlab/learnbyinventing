# %% [markdown]
# # Recursive Factorial (for Counting Outcomes)
#
# **Chapter:** Recursion &nbsp;·&nbsp; **Difficulty:** Medium &nbsp;·&nbsp; **ML/Stats concept:** Probability
#
# ### Problem
# `n!` (n factorial) counts the number of ways to order `n` items — the basis of the
# combinations and permutations used throughout probability. Write `factorial(n)` recursively.
#
# - base case: `factorial(0) = factorial(1) = 1`
# - recursive case: `n * factorial(n - 1)`

# %%
def factorial(n):
    """Return n! using recursion."""
    # TODO: base case
    # TODO: recursive case
    pass

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
import math

for n in range(0, 10):
    assert factorial(n) == math.factorial(n), f"factorial({n}) is wrong"
print("All tests passed!")

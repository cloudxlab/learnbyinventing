# %% [markdown]
# # Recursive Learning-Rate Decay Schedule
#
# **Chapter:** Recursion &nbsp;·&nbsp; **Difficulty:** Hard &nbsp;·&nbsp; **ML/Stats concept:** Gradient Descent
#
# ### Problem
# Training often **decays** the learning rate over time, so updates get smaller as training
# progresses. Define `decayed_lr(initial_lr, decay, n)` recursively:
#
# ```
# decayed_lr(initial_lr, decay, 0) = initial_lr
# decayed_lr(initial_lr, decay, n) = decay * decayed_lr(initial_lr, decay, n - 1)
# ```
#
#
# **Write your solution in `exercises/08_hard_recursive_lr_decay.py`**

# %%
def decayed_lr(initial_lr, decay, n):
    """Return the learning rate after n decay steps, using recursion."""
    # TODO: base case -- n == 0
    # TODO: recursive case
    pass

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
import math

initial_lr, decay = 0.1, 0.9
for n in range(0, 10):
    expected = initial_lr * decay ** n
    assert math.isclose(decayed_lr(initial_lr, decay, n), expected), f"decayed_lr(.., {n}) is wrong"
print("All tests passed!")

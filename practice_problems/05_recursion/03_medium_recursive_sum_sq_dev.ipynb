# %% [markdown]
# # Recursive Sum of Squared Deviations (for Variance)
#
# **Chapter:** Recursion &nbsp;·&nbsp; **Difficulty:** Medium &nbsp;·&nbsp; **ML/Stats concept:** Descriptive Statistics
#
# ### Problem
# Write `recursive_sum_sq_dev(data, mean_value)` that recursively computes
# `sum((x - mean_value) ** 2 for x in data)`.
#
# - base case: an empty list contributes `0`
# - recursive case: `(data[0] - mean_value) ** 2 + recursive_sum_sq_dev(data[1:], mean_value)`

# %%
def recursive_sum_sq_dev(data, mean_value):
    """Recursively compute sum((x - mean_value) ** 2 for x in data)."""
    # TODO: base case
    # TODO: recursive case
    pass

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
import math
import random

random.seed(6)
for _ in range(5):
    sample = [random.uniform(-20, 20) for _ in range(random.randint(0, 8))]
    m = random.uniform(-5, 5)
    expected = sum((x - m) ** 2 for x in sample)
    assert math.isclose(recursive_sum_sq_dev(sample, m), expected), \
        f"recursive_sum_sq_dev({sample}, {m}) is wrong"
print("All tests passed!")

# %% [markdown]
# # Recursive Product of a List (for Geometric Mean)
#
# **Chapter:** Recursion &nbsp;·&nbsp; **Difficulty:** Easy &nbsp;·&nbsp; **ML/Stats concept:** Descriptive Statistics
#
# ### Problem
# The **geometric mean** (used for growth rates and ratios) is the n-th root of the product of
# n numbers. Write `recursive_product(data)` that computes the product of a list, recursively.
#
# - base case: an empty list has product `1`
# - recursive case: `data[0] * recursive_product(data[1:])`

# %%
def recursive_product(data):
    """Return the product of a list of numbers, using recursion."""
    # TODO: base case -- what should an empty list's product be?
    # TODO: recursive case -- combine data[0] with recursive_product(data[1:])
    pass

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
import math
import random

random.seed(5)
for _ in range(5):
    sample = [random.randint(1, 5) for _ in range(random.randint(0, 6))]
    assert math.isclose(recursive_product(sample), math.prod(sample)), f"recursive_product({sample}) is wrong"
print("All tests passed!")

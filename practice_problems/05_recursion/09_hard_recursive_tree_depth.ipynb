# %% [markdown]
# # Recursive Depth of a Decision Tree
#
# **Chapter:** Recursion &nbsp;·&nbsp; **Difficulty:** Hard &nbsp;·&nbsp; **ML/Stats concept:** Decision Trees
#
# ### Problem
# A decision tree is naturally a nested structure: each node is either a **leaf**
# (`{"leaf": <label>}`) or an internal node with two children
# (`{"left": <node>, "right": <node>}`). Write `tree_depth(node)` that recursively computes the
# maximum depth of the tree (a lone leaf has depth 1).

# %%
def tree_depth(node):
    """`node` is either {"leaf": <label>} or {"left": <node>, "right": <node>}.
    Return the maximum depth of the tree rooted at `node` (a lone leaf has depth 1).
    """
    # TODO: base case -- node is a leaf
    # TODO: recursive case -- 1 + max depth of the two children
    pass

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
def ref_depth(node):
    if "leaf" in node:
        return 1
    return 1 + max(ref_depth(node["left"]), ref_depth(node["right"]))


tree = {
    "left": {"left": {"leaf": "A"}, "right": {"leaf": "B"}},
    "right": {"leaf": "C"},
}
assert tree_depth(tree) == ref_depth(tree) == 3, f"Expected 3, got {tree_depth(tree)}"
assert tree_depth({"leaf": "X"}) == 1
print("All tests passed!")

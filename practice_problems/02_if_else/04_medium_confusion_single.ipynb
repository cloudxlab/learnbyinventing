# %% [markdown]
# # Classify One Prediction (TP / FP / TN / FN)
#
# **Chapter:** If / Else &nbsp;·&nbsp; **Difficulty:** Medium &nbsp;·&nbsp; **ML/Stats concept:** Classification Metrics
#
# ### Problem
# For binary classification, every prediction falls into one of four buckets, based on the
# actual label and the predicted label (both `0` or `1`):
#
# | actual | predicted | category |
# |---|---|---|
# | 1 | 1 | TP (true positive) |
# | 0 | 1 | FP (false positive) |
# | 0 | 0 | TN (true negative) |
# | 1 | 0 | FN (false negative) |
#
# ```
# actual = 1
# predicted = 0
# ```
#
# Using `if`/`elif`, set `category` to the matching string: `"TP"`, `"FP"`, `"TN"`, or `"FN"`.

# %%
actual = 1
predicted = 0

# TODO: set category to "TP", "FP", "TN", or "FN" based on the table above
category = None

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
table = {(1, 1): "TP", (0, 1): "FP", (0, 0): "TN", (1, 0): "FN"}
expected = table[(actual, predicted)]
assert category == expected, f"Expected {expected!r}, got {category!r}"
print("All tests passed! category =", category)

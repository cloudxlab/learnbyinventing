# %% [markdown]
# # Flag a Single Outlier by Z-Score
#
# **Chapter:** If / Else &nbsp;·&nbsp; **Difficulty:** Easy &nbsp;·&nbsp; **ML/Stats concept:** Descriptive Statistics
#
# ### Problem
# A common rule of thumb: a point is an **outlier** if the absolute value of its z-score
# exceeds some threshold (commonly 3).
#
# ```
# z = 3.4
# threshold = 3
# ```
#
# Set `status` to `"outlier"` if `abs(z) > threshold`, otherwise `"normal"`.
#
#
# **Write your solution in `exercises/01_easy_outlier_flag.py`**

# %%
z = 3.4
threshold = 3

# TODO: set status to "outlier" if abs(z) > threshold, else "normal"
status = None

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
expected = "outlier" if abs(z) > threshold else "normal"
assert status == expected, f"Expected {expected!r}, got {status!r}"
print("All tests passed! status =", status)

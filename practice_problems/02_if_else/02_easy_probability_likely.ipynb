# %% [markdown]
# # Classify a Probability as Likely or Unlikely
#
# **Chapter:** If / Else &nbsp;·&nbsp; **Difficulty:** Easy &nbsp;·&nbsp; **ML/Stats concept:** Probability
#
# ### Problem
# Given a probability `p`, classify it as `"likely"` if `p >= 0.5`, otherwise `"unlikely"`.
#
# ```
# p = 0.72
# ```
#
# Store your answer in `label`.

# %%
p = 0.72

# TODO: set label to "likely" if p >= 0.5, else "unlikely"
label = None

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
expected = "likely" if p >= 0.5 else "unlikely"
assert label == expected, f"Expected {expected!r}, got {label!r}"
print("All tests passed! label =", label)

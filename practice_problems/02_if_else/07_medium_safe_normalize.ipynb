# %% [markdown]
# # Min-Max Normalize Without Dividing by Zero
#
# **Chapter:** If / Else &nbsp;·&nbsp; **Difficulty:** Medium &nbsp;·&nbsp; **ML/Stats concept:** Normalization
#
# ### Problem
# The min-max formula `(x - min_val) / (max_val - min_val)` breaks when `max_val == min_val`
# (a constant feature) — you'd divide by zero. Handle the edge case explicitly:
#
# - if `max_val == min_val`, the scaled value should just be `0.0`
# - otherwise, apply the normal formula
#
# ```
# x = 5
# min_val = 5
# max_val = 5
# ```
#
# Store the result in `scaled`.

# %%
x = 5
min_val = 5
max_val = 5

# TODO: handle the max_val == min_val edge case, else use the normal formula
scaled = None

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
import math

expected = 0.0 if max_val == min_val else (x - min_val) / (max_val - min_val)
assert scaled is not None, "scaled is still None -- fill in the if/else above."
assert math.isclose(scaled, expected), f"Expected {expected}, got {scaled}"
print("All tests passed! scaled =", scaled)

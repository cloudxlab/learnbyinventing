# %% [markdown]
# # Turn a Sigmoid Output into a Class Label
#
# **Chapter:** If / Else &nbsp;·&nbsp; **Difficulty:** Easy &nbsp;·&nbsp; **ML/Stats concept:** Neural Networks
#
# ### Problem
# A logistic regression model (or a single neuron) outputs an `activation` value in `(0, 1)`.
# To get a hard class prediction, threshold it at 0.5:
#
# ```
# activation = 0.63
# ```
#
# Set `predicted_class` to `1` if `activation >= 0.5`, otherwise `0`.
#
#
# **Write your solution in `exercises/03_easy_sigmoid_to_class.py`**

# %%
activation = 0.63

# TODO: set predicted_class to 1 if activation >= 0.5, else 0
predicted_class = None

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
expected = 1 if activation >= 0.5 else 0
assert predicted_class == expected, f"Expected {expected}, got {predicted_class}"
print("All tests passed! predicted_class =", predicted_class)

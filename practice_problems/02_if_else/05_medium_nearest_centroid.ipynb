# %% [markdown]
# # Assign a Point to the Nearest Centroid
#
# **Chapter:** If / Else &nbsp;·&nbsp; **Difficulty:** Medium &nbsp;·&nbsp; **ML/Stats concept:** Clustering
#
# ### Problem
# In k-means clustering, once you know a point's distance to each centroid, you assign the
# point to whichever centroid is closest.
#
# ```
# dist_to_a = 4.2
# dist_to_b = 3.7
# ```
#
# Set `assignment` to `"A"` or `"B"`, whichever centroid is closer.

# %%
dist_to_a = 4.2
dist_to_b = 3.7

# TODO: assign to "A" if dist_to_a is smaller, else "B"
assignment = None

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
expected = "A" if dist_to_a < dist_to_b else "B"
assert assignment == expected, f"Expected {expected!r}, got {assignment!r}"
print("All tests passed! assignment =", assignment)

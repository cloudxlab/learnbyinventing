# %% [markdown]
# # Sum of Squared Deviations
#
# **Chapter:** Loops &nbsp;·&nbsp; **Difficulty:** Easy &nbsp;·&nbsp; **ML/Stats concept:** Descriptive Statistics
#
# ### Problem
# Variance needs `sum((x - mean) ** 2 for x in data)`. Given a precomputed mean, use a loop to
# accumulate this sum (don't divide by anything yet — that's the next exercise).
#
# ```
# data = [12, 15, 14, 10, 100, 13, 11, 16, 9, 14]
# mean_value = 21.4  # precomputed mean of `data`
# ```
#
# Store the result in `sum_sq_dev`.

# %%
data = [12, 15, 14, 10, 100, 13, 11, 16, 9, 14]
mean_value = 21.4  # precomputed mean of `data`

# TODO: use a loop to compute the sum of squared deviations from the mean
sum_sq_dev = 0
# your loop here

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
import math

expected = sum((x - mean_value) ** 2 for x in data)
assert math.isclose(sum_sq_dev, expected), f"Expected {expected}, got {sum_sq_dev}"
print("All tests passed! sum_sq_dev =", sum_sq_dev)

# %% [markdown]
# # Run Several Iterations of Gradient Descent
#
# **Chapter:** Loops &nbsp;·&nbsp; **Difficulty:** Hard &nbsp;·&nbsp; **ML/Stats concept:** Gradient Descent
#
# ### Problem
# Simulate minimizing `f(w) = (w - target) ** 2` with gradient descent for a fixed number of
# steps. The gradient of `(w - target) ** 2` with respect to `w` is `2 * (w - target)`.
#
# ```
# target = 10
# w = 0.0
# learning_rate = 0.1
# epochs = 20
# ```
#
# Loop `epochs` times. Each iteration:
# 1. compute `gradient = 2 * (w - target)`
# 2. update `w = w - learning_rate * gradient`
# 3. append the current loss `(w - target) ** 2` to `loss_history`
#
# By the end, `w` should be much closer to `target`, and `loss_history` should generally
# decrease.
#
#
# **Write your solution in `exercises/09_hard_gradient_descent_loop.py`**

# %%
target = 10
w = 0.0
learning_rate = 0.1
epochs = 20
loss_history = []

# TODO: loop `epochs` times, updating w and appending to loss_history each time

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
import math

w_ref = 0.0
expected_history = []
for _ in range(epochs):
    grad = 2 * (w_ref - target)
    w_ref = w_ref - learning_rate * grad
    expected_history.append((w_ref - target) ** 2)

assert len(loss_history) == epochs, f"loss_history should have {epochs} entries, has {len(loss_history)}"
assert all(math.isclose(a, b) for a, b in zip(loss_history, expected_history)), "loss_history values are wrong"
assert math.isclose(w, w_ref), f"Expected w close to {w_ref}, got {w}"
assert loss_history[-1] < loss_history[0], "loss should decrease over training"
print("All tests passed! final w =", w, "| final loss =", loss_history[-1])

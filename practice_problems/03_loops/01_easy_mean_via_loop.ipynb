# %% [markdown]
# # Compute the Mean With a Loop
#
# **Chapter:** Loops &nbsp;·&nbsp; **Difficulty:** Easy &nbsp;·&nbsp; **ML/Stats concept:** Descriptive Statistics
#
# ### Problem
# Generalize "find the mean" to work on **any** list, not just three hardcoded numbers. Use a
# loop to accumulate the sum, then divide by the count.
#
# ```
# data = [12, 15, 14, 10, 100, 13, 11, 16, 9, 14]
# ```
#
# Store the result in `mean_value`.
#
#
# **Write your solution in `exercises/01_easy_mean_via_loop.py`**

# %%
data = [12, 15, 14, 10, 100, 13, 11, 16, 9, 14]

# TODO: use a loop to accumulate the total, then divide by len(data)
total = 0
# your loop here

mean_value = None

# %% [markdown]
# ### Test your solution
#
# Run the cell below. If you see `All tests passed!`, you're done.

# %%
import math
import statistics

expected = statistics.mean(data)
assert mean_value is not None, "mean_value is still None."
assert math.isclose(mean_value, expected), f"Expected {expected}, got {mean_value}"
print("All tests passed! mean_value =", mean_value)
